# %% [markdown]
# # <center> <span style="color:indigo">        Escuela de ML y DL Módulo 2</span> </center>
# ##  <center> <span style="color:DarkBlue">          Tarea 3. Sarcasmo en Noticias Distribuido </span>  </center>
# ##  <center> <span style="color:DarkBlue"> Nombre y Apellidos</span>  </center>
# ##  <center> <span style="color:DarkBlue"> Correo electrónico</span>  </center>
# ##  <center> <span style="color:DarkBlue"> Diciembre de 2021</span>  </center>
#
# ##  Contenido
# 1. <span style="color:DarkBlue">Planteamiento del problema (qué hacer)</span>
# 2. <span style="color:DarkBlue">Planteamiento de la solución (cómo se hizó)</span>
# 3. <span style="color:DarkBlue">Ejemplo de ejecución (código)</span>
# 4. <span style="color:DarkBlue">Conclusiones </span>
# 5. <span style="color:DarkBlue">Referencias</span>
#
#
# ## <span style="color:DarkBlue"> 1. Planteamiento del problema</span>
# Haciendo uso de lo aprendido en la Práctica 5 TensorFlow Distribuido:
#
# PARTE 1:
#
# * Ejecutar la práctica vista en clase, pero en un nodo del servidor.
# * Modificar y mejorar la estructura de la RNN para conseguir un resultado más certero.
#
# PARTE 2:
#
# * Ejecutar la nueva libreta que crearon, pero de manera distribuida en los 3 nodos del servidor. Eso es editando el archivo worker.py adaptándolo a la red de redes neuronales convolucionales (pueden usar el archivo adjunto para darse una idea)
# * Realizar un análisis considerando la velocidad de ejecución, velocidad de entrenamiento y calidad de resultados obtenidos.
#
# NOTA 1: Es necesario instalar en documento de "requirements.txt" en su ambiente de Anaconda en los 3 nodos del servidor. Recuerda usar la instrucción "pip install -r requirements.txt" (Sin las comillas)
#
# NOTA: Se calificará también su análisis del Dataset; su analogía y razonamiento de qué columnas usar y cuáles descartar. A diferencia de la clase que se vio una clasificación binaria, en este Dataset estaremos manejando más clases.
#
# ## <span style="color:DarkciónBlue"> 2. Planteamiento de la solución</span>
# Describir como se plantea la solución, teorías que utilizas o metodologías
#
# El código es:

# %%
#3 Código y ejemplo de la solución

#Librerias utilizadas
import matplotlib.pyplot as plt
import numpy as np
import math

#Código de la solución

#Funciones

## 3. Ejecutar para ver ejemplo

# %% [markdown]
# ## <span style="color:DarkciónBlue"> 4. Conclusiones</span>
#
# Agallazgos, mejoras a manera de conclusiones

# %% [markdown]
# ## <span style="color:DarkciónBlue"> 5. Referencias</span>
# ### Documentos consultados

# %% [markdown]
# # Fin
